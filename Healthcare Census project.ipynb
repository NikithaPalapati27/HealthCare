# %% [markdown]
# # Healthcare Census Project

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\pynik\\Desktop\\Python assignment1'

# %%
data=pd.read_csv('census_2011.csv')

# %%
data
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %% [markdown]
# # Problem statement 1

# %%
The census 2011 file contains many fields, which we may not use. Remove some columns so that we are left with only relevant data.
We may need the following columns.
	State name
	District name
	Population
	Male
	Female
	Literate
	Male_Literate
	Female_Literate
	Rural_Households
	Urban_Households
	Households
	Age_Group_0_29
	Age_Group_30_49
	Age_Group_50
	Age not stated
Import the data to pandas and keep only the required columns.
# Out:
#   Cell In[7], line 3
#     	State name
#     ^
# SyntaxError: invalid non-printable character U+F0D8

# %%
d1=data.loc[:,['State name','District name','Population','Male','Female','Literate','Male_Literate','Female_Literate','Rural_Households','Urban_Households','Households','Age_Group_0_29','Age_Group_30_49','Age_Group_50','Age not stated']]

# %%
d1
# Out:
#                       State name              District name  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Male_Literate  Female_Literate  \
# ...

# %%
d1.columns
# Out:
# Index(['State name', 'District name', 'Population', 'Male', 'Female',
#        'Literate', 'Male_Literate', 'Female_Literate', 'Rural_Households',
#        'Urban_Households', 'Households', 'Age_Group_0_29', 'Age_Group_30_49',
#        'Age_Group_50', 'Age not stated'],
#       dtype='object')

# %% [markdown]
# # Problem statement 2

# %% [markdown]
# For uniformity in the datasets and taking into consideration the census year, we need to rename some columns.
# 	State name  to State/UT
# 	District name  to District
# 	Male_Literate to Literate_Male
# 	Female_Literate to Literate_Female
# 	Rural_Households  to Households_Rural
# 	Urban_ Households  to Households_Urban
# 	Age_Group_0_29 to Young_and_Adult
# 	Age_Group_30_49 to Middle_Aged
# 	Age_Group_50 to Senior_Citizen
# 	Age not stated to Age_Not_Stated

# %%
new_column_names = {
    'State name': 'State/UT',
    'District name': 'District',
    'Male_Literate': 'Literate_Male',
    'Female_Literate': 'Literate_Female',
    'Rural_Households': 'Households_Rural',
    'Urban_ Households': 'Households_Urban',
    'Age_Group_0_29': 'Young_and_Adult',
    'Age_Group_30_49': 'Middle_Aged',
    'Age_Group_50': 'Senior_Citizen',
    'Age not stated': 'Age_Not_Stated'
}

d1 = d1.rename(columns=new_column_names)

# %%
d1
# Out:
#                         State/UT                   District  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %% [markdown]
# # Problem Statement 3

# %% [markdown]
# The State/UT names are in all caps in the census data, For uniformity across datasets we use the names so that only the first character of each word in the name is in upper case and the rest are in lower case. However, if the word is “and” then it should be all lowercase.
# Examples:
# 	Andaman and Nicobar Islands
# 	Arunachal Pradesh
# 	Bihar
#  using pandas in csv file

# %%
def convert_state_name(name):
    words = name.lower().split()
    converted_words = [word.title() if word != 'and' else word for word in words]
    return ' '.join(converted_words)


d1['State/UT'] = d1['State/UT'].apply(convert_state_name)

# %%
d1
# Out:
#                         State/UT                   District  Population  \
# 0              Jammu and Kashmir                    Kupwara    870354.0
# 1              Jammu and Kashmir                     Badgam    753745.0
# 2              Jammu and Kashmir                Leh(Ladakh)    133487.0
# 3              Jammu and Kashmir                     Kargil    140802.0
# 4              Jammu and Kashmir                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  Pondicherry                       Mahe     41816.0
# 636                  Pondicherry                   Karaikal    200222.0
# 637  Andaman and Nicobar Islands                   Nicobars     36842.0
# 638  Andaman and Nicobar Islands  North  AND Middle Andaman    105597.0
# 639  Andaman and Nicobar Islands              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %% [markdown]
# # Problem Statement 4

# %% [markdown]
# 	In 2014 Telangana was formed after it split from Andhra Pradesh, The districts that were included in Telangana are stored in Data/Telangana.txt . Read the text file and Rename the State/UT From “Andhra Pradesh” to “Telangana” for the given districts.
#
# 	In 2019 Laddakh was formed after it split from Jammu and Kashmir, which included the districts Leh and Kargil.  Rename the State/UT From “Jammu and Kashmir” to “Laddakh” for the given districts.

# %%
districts = pd.read_csv('Telangana.txt')
districts
# Out:
#       Adilabad
# 0    Nizamabad
# 1   Karimnagar
# 2        Medak
# 3    Hyderabad
# 4   Rangareddy
# 5  Mahbubnagar
# 6     Nalgonda
# 7     Warangal
# 8      Khammam

# %%
r1= [
    'Adilabad',
    'Nizamabad',
    'Karimnagar',
    'Medak',
    'Hyderabad',
    'Rangareddy',
    'Mahbubnagar',
    'Nalgonda',
    'Warangal',
    'Khammam'
]
d1.loc[d1['District'].isin (r1), 'State/UT' ] = 'Telangana'
r2=['Leh','Kargil']
d1.loc[d1['District'].isin(r2),'State/UT']='Laddakh'
d1.to_csv('updated1_file.csv', index=False)

# %%
d1
# Out:
#                         State/UT                   District  Population  \
# 0              Jammu and Kashmir                    Kupwara    870354.0
# 1              Jammu and Kashmir                     Badgam    753745.0
# 2              Jammu and Kashmir                Leh(Ladakh)    133487.0
# 3                        Laddakh                     Kargil    140802.0
# 4              Jammu and Kashmir                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  Pondicherry                       Mahe     41816.0
# 636                  Pondicherry                   Karaikal    200222.0
# 637  Andaman and Nicobar Islands                   Nicobars     36842.0
# 638  Andaman and Nicobar Islands  North  AND Middle Andaman    105597.0
# 639  Andaman and Nicobar Islands              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %% [markdown]
# # Problem statement 5

# %% [raw]
# Find and store the percentage of data missing for each column.
# Some data can be found and filled in by using information from other cells. Try to find the correct data by using information from other cells and filling it in. Find and store the percentage of data missing for each column.
#
# Hint:
# 	Population = Male + Female
# 	Literate = Literate_Male + Literate_Female
# 	Population  = Young_and_Adult+  Middle_Aged + Senior_Citizen + Age_Not_Stated
# 	Households = Households_Rural + Households_Urban
#
# Create a visualization that compares the amount of missing data before and after the data-filling process was done.

# %%
d1.isnull().sum()
# Out:
# State/UT             0
# District             0
# Population          30
# Male                30
# Female              33
# Literate            36
# Literate_Male       31
# Literate_Female     27
# Households_Rural    42
# Urban_Households    33
# Households          32
# Young_and_Adult     31
# Middle_Aged         30
# Senior_Citizen      31
# Age_Not_Stated      35
# dtype: int64

# %%
missing_percentage = (d1.isnull().sum() / len(d1)) * 100
missing_data = pd.DataFrame({'Column': d1.columns, 'Missing Percentage': missing_percentage}).sort_values('Missing Percentage', ascending=False)
missing_data
# Out:
#                             Column  Missing Percentage
# Households_Rural  Households_Rural             6.56250
# Literate                  Literate             5.62500
# Age_Not_Stated      Age_Not_Stated             5.46875
# Female                      Female             5.15625
# Urban_Households  Urban_Households             5.15625
# Households              Households             5.00000
# Literate_Male        Literate_Male             4.84375
# Young_and_Adult    Young_and_Adult             4.84375
# Senior_Citizen      Senior_Citizen             4.84375
# Population              Population             4.68750
# Male                          Male             4.68750
# Middle_Aged            Middle_Aged             4.68750
# Literate_Female    Literate_Female             4.21875
# State/UT                  State/UT             0.00000
# District                  District             0.00000

# %% [markdown]
# d1['Male'].fillna(d1['Male'].mean(),inplace=True)
# d1['Female'].fillna(d1['Female'].mean(),inplace=True)
# d1['Literate_Male'].fillna(d1['Literate_Male'].mean(),inplace=True)
# d1['Literate_Female'].fillna(d1['Literate_Female'].mean(),inplace=True)
# d1['Households_Rural'].fillna(d1['Households_Rural'].mean(),inplace=True)
# d1['Urban_Households'].fillna(d1['Urban_Households'].mean(),inplace=True)
# d1['Young_and_Adult'].fillna(d1['Young_and_Adult'].mean(),inplace=True)
# d1['Middle_Aged'].fillna(d1['Middle_Aged'].mean(),inplace=True)
# d1['Senior_Citizen'].fillna(d1['Senior_Citizen'].mean(),inplace=True)
# d1['Age_Not_Stated'].fillna(d1['Age_Not_Stated'].mean(),inplace=True)

# %%
d1['Population'] = d1['Population'].fillna(d1['Male'] + d1['Female'])
d1['Literate'] = d1['Literate'].fillna(d1['Literate_Male'] + d1['Literate_Female'])
d1['Population'] = d1['Population'].fillna(d1['Young_and_Adult'] + d1['Middle_Aged'] + d1['Senior_Citizen'] + d1['Age_Not_Stated'])
d1['Households'] = d1['Households'].fillna(d1['Households_Rural'] + d1['Urban_Households'])
m2 = (d1.isnull().sum() / len(d1)) * 100
missing_data['Missing Percentage After Fill'] = m2
plt.figure(figsize=(10, 6))
plt.barh(missing_data['Column'], missing_data['Missing Percentage'], label='Before Fill')
plt.barh(missing_data['Column'], missing_data['Missing Percentage After Fill'], label='After Fill')
plt.xlabel('Missing Percentage')
plt.ylabel('Column')
plt.title('Missing Data Before and After Filling')
plt.legend()
plt.tight_layout()
plt.show()

# %%
def fix_state_names(data):
    
    state_mapping = {
        'Pondicherry': 'Puducherry',
        'Orissa': 'Odisha',
        'Nct Of Delhi': 'Delhi',
        
    }

   
    data['State/UT'] = data['State/UT'].replace(state_mapping)

    return data

d1 = fix_state_names(d1)

# %% [markdown]
# # Problem statement 6

# %%
d1.to_csv('census2.csv', index=False)

# %% [markdown]
# # Problem statement 7

# %%
housing_data = pd.read_csv('housing.csv')
housing_data
# Out:
#       State Code                 State Name  District Code  \
# 0              1            JAMMU & KASHMIR              1
# 1              1            JAMMU & KASHMIR              1
# 2              1            JAMMU & KASHMIR              1
# 3              1            JAMMU & KASHMIR              2
# 4              1            JAMMU & KASHMIR              2
# ...          ...                        ...            ...
# 1903          35  ANDAMAN & NICOBAR ISLANDS            639
# 1904          35  ANDAMAN & NICOBAR ISLANDS            639
# 1905          35  ANDAMAN & NICOBAR ISLANDS            640
# 1906          35  ANDAMAN & NICOBAR ISLANDS            640
# 1907          35  ANDAMAN & NICOBAR ISLANDS            640
#
#                 District Name  Tehsil Code              Tehsil Name  \
# 0                     Kupwara            0                  Kupwara
# 1                     Kupwara            0                  Kupwara
# ...

# %%
housing_data = housing_data[['District Name', 'Rural/Urban', 'Total Number of households', 'Total Number of Livable', 'Total Number of Dilapidated', 'Latrine_premise']]
housing_data.head()
rural = housing_data[housing_data['Rural/Urban'] == 'Rural']
urban = housing_data[housing_data['Rural/Urban'] == 'Urban']
rural.drop(columns =['Rural/Urban'],inplace = True)
urban.drop(columns = ['Rural/Urban'],inplace = True)
updated_housing = urban.merge(rural,how = 'left', on = 'District Name',suffixes = ['_urban','_rural'])
merged_data = pd.merge(updated_housing,d1,how = 'inner',left_on = 'District Name',right_on = 'District')
merged_data['Households_Rural_Livable'] = merged_data['Households_Rural'] * merged_data['Total Number of Livable_rural'] / 100
merged_data['Households_Rural_Dilapidated'] = merged_data['Households_Rural'] * merged_data['Total Number of Dilapidated_rural'] / 100
merged_data['Households_Rural_Toilet_Premise'] = merged_data['Households_Rural'] * merged_data['Latrine_premise_rural'] / 100
merged_data['Households_Urban_Livable'] = merged_data['Urban_Households'] * merged_data['Total Number of Livable_urban'] / 100
merged_data['Households_Urban_Dilapidated'] = merged_data['Urban_Households'] * merged_data['Total Number of Dilapidated_urban'] / 100
merged_data['Households_Urban_Toilet_Premise'] = merged_data['Urban_Households'] * merged_data['Latrine_premise_urban'] / 100
final_data = merged_data[['District', 'Households_Rural', 'Households_Rural_Livable', 'Households_Rural_Dilapidated',
           'Households_Rural_Toilet_Premise', 'Urban_Households', 'Households_Urban_Livable',
           'Households_Urban_Dilapidated', 'Households_Urban_Toilet_Premise']]
final_data
# Out:
# C:\Users\pynik\AppData\Local\Temp\ipykernel_13504\367767347.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rural.drop(columns =['Rural/Urban'],inplace = True)
# C:\Users\pynik\AppData\Local\Temp\ipykernel_13504\367767347.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   urban.drop(columns = ['Rural/Urban'],inplace = True)
#           District  Households_Rural  Households_Rural_Livable  \
# 0          Kupwara          158438.0                 92052.478
# 1           Badgam          160649.0                 74380.487
# 2      Leh(Ladakh)           36920.0                 19013.800
# ...

# %%
final_data.to_csv('housing.csv', index=False)

# %%
l1 = d1['District'].unique()
l2 = housing_data['District Name'].unique()
print(set(l1).symmetric_difference(set(l2)))
# Out:
# {'Lahul AND Spiti', 'Puducherry', 'LAKSHADWEEP', 'Dadra AND Nagar Haveli', 'Dadra & Nagar Haveli', 'PONDICHERRY', 'North  AND Middle Andaman', 'Lakshadweep', 'North  & Middle Andaman', 'Lahul & Spiti'}

# %% [markdown]
# # Problem Statement 8

# %%
second=final_data.copy()
second['State/UT']=d1['State/UT']
second['Households']=d1['Households']
second=second.groupby('State/UT')[['Households','Households_Rural','Urban_Households','Households_Rural_Toilet_Premise','Households_Urban_Toilet_Premise']].sum()
second['Households for 100']=((second['Households_Rural']+second['Urban_Households'])/100)
second['Households for 100']=second['Households for 100'].round()
fig=plt.figure(figsize=(10,10))
plt.title('Number of households for 100 people')
plt.xlabel('Number of households for 100 people')
plt.ylabel('States and Union Territories')
plt.barh(second.index,second['Households for 100'],color='orange')
# Out:
# <BarContainer object of 37 artists>

# %%
second=second.groupby('State/UT')[['Households','Households_Rural','Urban_Households','Households_Rural_Toilet_Premise','Households_Urban_Toilet_Premise']].sum()
second['Toilet_Premise']=((second['Households_Rural_Toilet_Premise']+second['Households_Urban_Toilet_Premise'])/(second['Households']))*100
second['Toilet_Premise']=second['Toilet_Premise'].round()
fig=plt.figure(figsize=(10,10))
plt.title('Percentage of households that have toilet(s) in premise to the total number of households.')
plt.xlabel('Percantage of households having toilets  in premise')
plt.ylabel('States and Union Territories')
plt.barh(second.index,second['Toilet_Premise'],color='red')
# Out:
# <BarContainer object of 37 artists>

# %%
rural=final_data['Households_Rural'].sum()
urban=final_data['Urban_Households'].sum()
ratio = (urban / rural)*100
print("Urban to Rural Households Ratio:", ratio)
# Out:
# Urban to Rural Households Ratio: 50.39497025192594

# %%
labels = ['Households_Urban','Households_Rural']
values = [urban, rural]
plt.figure(figsize=(4,5))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Rural and Urban Households');

# %% [markdown]
# # Problem Statement 9

# %%
housing=final_data[['District','Households_Rural','Urban_Households']]
census=d1[['District','Households_Rural','Urban_Households']]

# %%
housing=housing.groupby('District')[['Households_Rural','Urban_Households']].sum()
census=census.groupby('District')[['Households_Rural','Urban_Households']].sum()
housing['percent_diff_rural']=((housing['Households_Rural']-census['Households_Rural'])/census['Households_Rural'])*100
housing['percent_diff_urban']=((housing['Urban_Households']-census['Urban_Households'])/census['Urban_Households'])*100

# %%
housing
# Out:
#              Households_Rural  Urban_Households  percent_diff_rural  \
# District
# Adilabad                  0.0          220248.0                 NaN
# Agra                 496971.0          406852.0                 0.0
# Ahmadabad            353169.0         1845383.0                 0.0
# Ahmadnagar          1041393.0          282011.0                 0.0
# Aizawl                20570.0           80341.0                 0.0
# ...                       ...               ...                 ...
# Yadgir               207787.0           55208.0                 0.0
# Yamunanagar          214464.0          143259.0                 0.0
# Yanam                     0.0           15519.0                 NaN
# Yavatmal             629243.0          168889.0                 0.0
# Zunheboto             31267.0            6044.0                 0.0
#
#              percent_diff_urban
# District
# Adilabad                    0.0
# Agra                        0.0
# ...

# %%
census
# Out:
#              Households_Rural  Urban_Households
# District
# Adilabad                  0.0          220248.0
# Agra                 496971.0          406852.0
# Ahmadabad            353169.0         1845383.0
# Ahmadnagar          1041393.0          282011.0
# Aizawl                20570.0           80341.0
# ...                       ...               ...
# Yadgir               207787.0           55208.0
# Yamunanagar          214464.0          143259.0
# Yanam                     0.0           15519.0
# Yavatmal             629243.0          168889.0
# Zunheboto             31267.0            6044.0
#
# [634 rows x 2 columns]

# %% [markdown]
# # Problem statement 10

# %% [markdown]
# Import the hospital data from Data/hospitals.csv and make the necessary changes to the header (Do not change the original file).
# The header uses acronyms that are defined in metadata.csv. Find the data and rename the headers so that it is more understandable to users who are not familiar with the acronyms. The First cell in the header is missing which should be renamed to State/UT. Rename the other headers in a uniform format

# %%
d2=pd.read_csv('hospitals.csv')

# %%
d2
# Out:
#                    Unnamed: 0     PHC    CHC    SDH     DH Hospitals  \
# 0   Andaman & Nicobar Islands      27      4    NaN      3        34
# 1              Andhra Pradesh    1417    198     31     20      1666
# 2           Arunachal Pradesh     122     62    NaN     15       199
# 3                       Assam    1007    166     14     33      1220
# 4                       Bihar    2007     63     33     43      2146
# 5                  Chandigarh      40      2      1      4        47
# 6                Chhattisgarh     813    166     12     32      1023
# 7        Dadra & Nagar Haveli       9      2      1      1        13
# 8                 Daman & Diu       4      2    NaN      2         8
# 9                       Delhi     534     25      9     47       615
# 10                        Goa      31      4      2      3        40
# 11                    Gujarat    1770    385     44     37      2236
# 12                    Haryana     500    131     24     28       683
# ...

# %%
column={d2.columns[0]:'State/UT'}

# %%
meta=pd.read_csv('metadata.csv')
meta
# Out:
#                                    Acronyms
# 0  Number of Primary Health Centers(PHCs),
# 1          Community Health Centers(CHCs),
# 2   Sub-District/Divisional Hospitals(SDHs)
# 3                  District Hospitals(DHs)

# %%
d=dict(zip(d2.columns[1:],meta['Acronyms']))
for k,v in d.items():
    d[k]=v.strip().replace(',','')
d
# Out:
# {'PHC': 'Number of Primary Health Centers(PHCs)',
#  'CHC': 'Community Health Centers(CHCs)',
#  'SDH': 'Sub-District/Divisional Hospitals(SDHs)',
#  'DH': 'District Hospitals(DHs)'}

# %%
d2=d2.rename(columns=d)
d2=d2.rename(columns=column)
d2
# Out:
#                      State/UT Number of Primary Health Centers(PHCs)  \
# 0   Andaman & Nicobar Islands                                     27
# 1              Andhra Pradesh                                   1417
# 2           Arunachal Pradesh                                    122
# 3                       Assam                                   1007
# 4                       Bihar                                   2007
# 5                  Chandigarh                                     40
# 6                Chhattisgarh                                    813
# 7        Dadra & Nagar Haveli                                      9
# 8                 Daman & Diu                                      4
# 9                       Delhi                                    534
# 10                        Goa                                     31
# 11                    Gujarat                                   1770
# 12                    Haryana                                    500
# ...

# %% [markdown]
# # Problem Statement 11

# %% [markdown]
# The State/UT names have some different formats compared to other census and housing data. Manually identify those differences and fix them so that the State/UT names match exactly with the census and housing data.
# A function should be created to perform this operation. Since the same operation is required for another dataset as well.
# After the process save the data in a CSV file named “all_hospitals.csv” in the “Clean_Data” folder

# %%
def fix_state_names(data):
    
    state_mapping = {
        'Dadra & Nagar Haveli': 'Dadra and Nagar Haveli',
        'Daman & Diu': 'Daman and Diu',
        'Jammu & Kashmir': 'Jammu and Kashmir',
        'Andaman & Nicobar Islands': 'Andaman and Nicobar Islands',
    }

   
    data['State/UT'] = data['State/UT'].replace(state_mapping)

    return data
d2 = fix_state_names(d2)

# %%
d2
# Out:
#                        State/UT Number of Primary Health Centers(PHCs)  \
# 0   Andaman and Nicobar Islands                                     27
# 1                Andhra Pradesh                                   1417
# 2             Arunachal Pradesh                                    122
# 3                         Assam                                   1007
# 4                         Bihar                                   2007
# 5                    Chandigarh                                     40
# 6                  Chhattisgarh                                    813
# 7        Dadra and Nagar Haveli                                      9
# 8                 Daman and Diu                                      4
# 9                         Delhi                                    534
# 10                          Goa                                     31
# 11                      Gujarat                                   1770
# ...

# %%
d2.to_csv('all_hospitals.csv', index=False)

# %% [markdown]
# # Problem statement 12

# %% [markdown]
# Visually represent how many hospital beds are there for every 10,000 people in each state or union territory. The national value should also be represented in the same visualization such that the value for each state can be compared to it.

# %%
hospital_data= pd.read_csv('Clean_Data/all_hospitals.csv')

# %%
import seaborn as sns
populations=d1.groupby('State/UT')['Population'].sum()
population_data=pd.DataFrame(populations)
updated_hospital_data=pd.merge(hospital_data,population_data,on='State/UT',how='outer') 
l=updated_hospital_data[updated_hospital_data['State/UT']=='Laddakh'].index
updated_hospital_data.drop(l,inplace=True)
updated_hospital_data
Total_population=updated_hospital_data['Population'].sum().astype(int)
updated_hospital_data.loc[updated_hospital_data['State/UT']=='All India','Population']=Total_population
updated_hospital_data['HospitalBeds'] = updated_hospital_data['HospitalBeds'].str.replace(',', '').astype(int)
updated_hospital_data['Beds_per_10k']=round(updated_hospital_data['HospitalBeds']/(updated_hospital_data['Population']/10000))
updated_hospital_data['Beds_per_10k']=round(updated_hospital_data['HospitalBeds']/(updated_hospital_data['Population']/10000))
sorted_data = updated_hospital_data.sort_values('Beds_per_10k', ascending=False)

# Plot the data
plt.figure(figsize=(15, 7))
sns.barplot(x='State/UT',y='Beds_per_10k',data=sorted_data)
plt.xticks(rotation=90);

# %% [markdown]
# # Problem Statement 13

# %%
govt=pd.read_csv('Data/government_hospitals.csv',skiprows=[1])
govt
# Out:
#                    States/UTs  Rural hospitals  Unnamed: 2  Urban hospitals  \
# 0              Andhra Pradesh              193        6480               65
# 1          Arunachal Pradesh*              208        2136               10
# 2                       Assam             1176       10944               50
# 3                       Bihar              930        6083              103
# 4                Chhattisgarh              169        5070               45
# 5                        Goa*               17        1405               25
# 6                     Gujarat              364       11715              122
# 7                    Haryana*              609        6690               59
# 8           Himachal Pradesh*              705        5665               96
# 9             Jammu & Kashmir               56        7234               76
# 10                  Jharkhand              519        5842               36
# ...

# %%
newcols={
    'States/UTs':'State/UT',
    'Rural hospitals':'Rural_Government_Hospitals',
    'Unnamed: 2':'Rural_Government_Beds',
    'Urban hospitals':'Urban_Government_Hospitals',
    'Unnamed: 4':'Urban_Government_Beds',
    'As on':'Last_Updated'
}
govt = govt.rename(columns=newcols)

# %%
govt
# Out:
#                      State/UT  Rural_Government_Hospitals  \
# 0              Andhra Pradesh                         193
# 1          Arunachal Pradesh*                         208
# 2                       Assam                        1176
# 3                       Bihar                         930
# 4                Chhattisgarh                         169
# 5                        Goa*                          17
# 6                     Gujarat                         364
# 7                    Haryana*                         609
# 8           Himachal Pradesh*                         705
# 9             Jammu & Kashmir                          56
# 10                  Jharkhand                         519
# 11                 Karnataka*                        2471
# 12                     Kerala                         981
# 13             Madhya Pradesh                         334
# 14                Maharashtra                         273
# ...

# %%
govt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   State/UT                    37 non-null     object
#  1   Rural_Government_Hospitals  37 non-null     int64
#  2   Rural_Government_Beds       37 non-null     int64
#  3   Urban_Government_Hospitals  37 non-null     int64
#  4   Urban_Government_Beds       37 non-null     int64
#  5   Last_Updated                36 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 1.9+ KB

# %% [markdown]
# # problem statement 14

# %%
govt['Last_Updated'] = pd.to_datetime(govt['Last_Updated'], format='%d.%m.%Y')
govt['Last_Updated'] = govt['Last_Updated'].dt.strftime('%Y-%m-%d')

# %%
govt
# Out:
#                      State/UT  Rural_Government_Hospitals  \
# 0              Andhra Pradesh                         193
# 1          Arunachal Pradesh*                         208
# 2                       Assam                        1176
# 3                       Bihar                         930
# 4                Chhattisgarh                         169
# 5                        Goa*                          17
# 6                     Gujarat                         364
# 7                    Haryana*                         609
# 8           Himachal Pradesh*                         705
# 9             Jammu & Kashmir                          56
# 10                  Jharkhand                         519
# 11                 Karnataka*                        2471
# 12                     Kerala                         981
# 13             Madhya Pradesh                         334
# 14                Maharashtra                         273
# ...

# %%
def fix_state_names(data):
    
    state_mapping = {
        'Dadra & Nagar Haveli': 'Dadra and Nagar Haveli',
        'Daman & Diu': 'Daman and Diu',
        'Jammu & Kashmir': 'Jammu and Kashmir',
        'Andaman & Nicobar Islands': 'Andaman and Nicobar Islands',
    }

   
    data['State/UT'] = data['State/UT'].replace(state_mapping)

    return data
govt = fix_state_names(govt)
govt['State/UT'] = govt['State/UT'].str.rstrip('*')

# %%
govt
# Out:
#                        State/UT  Rural_Government_Hospitals  \
# 0                Andhra Pradesh                         193
# 1             Arunachal Pradesh                         208
# 2                         Assam                        1176
# 3                         Bihar                         930
# 4                  Chhattisgarh                         169
# 5                           Goa                          17
# 6                       Gujarat                         364
# 7                       Haryana                         609
# 8              Himachal Pradesh                         705
# 9             Jammu and Kashmir                          56
# 10                    Jharkhand                         519
# 11                    Karnataka                        2471
# 12                       Kerala                         981
# 13               Madhya Pradesh                         334
# 14                  Maharashtra                         273
# ...

# %%
govt.to_csv('government_hospital.csv', index=False)

# %% [markdown]
# # Problem Statement 15

# %%
govt1= pd.read_csv('Clean_Data/government_hospital.csv')
govt1
# Out:
#                        State/UT  Rural_Government_Hospitals  \
# 0                Andhra Pradesh                         193
# 1             Arunachal Pradesh                         208
# 2                         Assam                        1176
# 3                         Bihar                         930
# 4                  Chhattisgarh                         169
# 5                           Goa                          17
# 6                       Gujarat                         364
# 7                       Haryana                         609
# 8              Himachal Pradesh                         705
# 9             Jammu and Kashmir                          56
# 10                    Jharkhand                         519
# 11                    Karnataka                        2471
# 12                       Kerala                         981
# 13               Madhya Pradesh                         334
# 14                  Maharashtra                         273
# ...

# %%
populations=d1.groupby('State/UT')['Population'].sum()
population_data=pd.DataFrame(populations)
govt1=pd.merge(govt1,population_data,on='State/UT',how='outer')
govt1
# Out:
#                        State/UT  Rural_Government_Hospitals  \
# 0                Andhra Pradesh                       193.0
# 1             Arunachal Pradesh                       208.0
# 2                         Assam                      1176.0
# 3                         Bihar                       930.0
# 4                  Chhattisgarh                       169.0
# 5                           Goa                        17.0
# 6                       Gujarat                       364.0
# 7                       Haryana                       609.0
# 8              Himachal Pradesh                       705.0
# 9             Jammu and Kashmir                        56.0
# 10                    Jharkhand                       519.0
# 11                    Karnataka                      2471.0
# 12                       Kerala                       981.0
# 13               Madhya Pradesh                       334.0
# 14                  Maharashtra                       273.0
# ...

# %%
hospitals= pd.read_csv('Clean_Data/all_hospitals.csv', usecols=['State/UT', 'HospitalBeds'])
govt1= pd.merge(govt1, hospitals, on='State/UT', how='left')

govt1
# Out:
#                        State/UT  Rural_Government_Hospitals  \
# 0                Andhra Pradesh                       193.0
# 1             Arunachal Pradesh                       208.0
# 2                         Assam                      1176.0
# 3                         Bihar                       930.0
# 4                  Chhattisgarh                       169.0
# 5                           Goa                        17.0
# 6                       Gujarat                       364.0
# 7                       Haryana                       609.0
# 8              Himachal Pradesh                       705.0
# 9             Jammu and Kashmir                        56.0
# 10                    Jharkhand                       519.0
# 11                    Karnataka                      2471.0
# 12                       Kerala                       981.0
# 13               Madhya Pradesh                       334.0
# 14                  Maharashtra                       273.0
# ...

# %%
govt1['Total Beds'] = (govt1['Rural_Government_Beds'] + govt1['Urban_Government_Beds']+govt1['HospitalBeds'].astype(float))/ (govt1['Population'])
govt1.sort_values('Total Beds', inplace=True)
states_with_lowest_beds = govt1.head(3)
states = states_with_lowest_beds['State/UT']
beds = states_with_lowest_beds['Total Beds']
plt.bar(states, beds)
plt.xlabel('State/UT')
plt.ylabel('Total Beds')
plt.title('States with the Lowest Beds')
plt.show()

# %%
state_with_least_hospitals = states_with_lowest_beds.loc[(states_with_lowest_beds['Rural_Government_Hospitals']+states_with_lowest_beds['Urban_Government_Hospitals']).idxmin()]['State/UT']
print(f"The state with the least number of government hospitals among the three states is: {state_with_least_hospitals}")
# Out:
# The state with the least number of government hospitals among the three states is: Jharkhand

# %% [markdown]
# # Problem Statement 16

# %%
govt1
# Out:
#                        State/UT  Rural_Government_Hospitals  \
# 3                         Bihar                       930.0
# 10                    Jharkhand                       519.0
# 26                Uttar Pradesh                      4442.0
# 4                  Chhattisgarh                       169.0
# 13               Madhya Pradesh                       334.0
# 7                       Haryana                       609.0
# 24                    Telangana                       802.0
# 20                       Punjab                       510.0
# 2                         Assam                      1176.0
# 21                    Rajasthan                       602.0
# 6                       Gujarat                       364.0
# 15                      Manipur                        23.0
# 14                  Maharashtra                       273.0
# 27                  Uttarakhand                       410.0
# 28                  West Bengal                      1272.0
# ...

# %%
hospitals= pd.read_csv('Clean_Data/all_hospitals.csv', usecols=['State/UT', 'HospitalBeds'])
govt1 = pd.merge(govt1, hospitals, on='State/UT', how='left')
govt1
# Out:
#                        State/UT  Rural_Government_Hospitals  \
# 0                         Bihar                       930.0
# 1                     Jharkhand                       519.0
# 2                 Uttar Pradesh                      4442.0
# 3                  Chhattisgarh                       169.0
# 4                Madhya Pradesh                       334.0
# 5                       Haryana                       609.0
# 6                     Telangana                       802.0
# 7                        Punjab                       510.0
# 8                         Assam                      1176.0
# 9                     Rajasthan                       602.0
# 10                      Gujarat                       364.0
# 11                      Manipur                        23.0
# 12                  Maharashtra                       273.0
# 13                  Uttarakhand                       410.0
# 14                  West Bengal                      1272.0
# ...

# %%
import seaborn as sns
govt1['Expected_beds']=round(govt1['Population']/1000)*3
govt1['Available_beds']=govt1['Rural_Government_Beds']+govt1['Urban_Government_Beds']+govt1['HospitalBeds'].astype(float)
govt1['Bed_gap']=govt1['Expected_beds']-govt1['Available_beds']
bar_colors = ['#1f77b4', '#ff7f0e']
sns.barplot(data = govt1, x = 'State/UT', y = 'Expected_beds', color = bar_colors[0],label = 'Expected Beds')
sns.barplot(data = govt1, x = 'State/UT', y = 'Available_beds', color = bar_colors[1],label = 'Actual Beds',alpha = 0.3)
plt.xticks(rotation=90)
plt.xlabel('States')
plt.ylabel('Hospital beds')
plt.title('Expected and available beds in hospitals')
plt.legend()
plt.show()

# %% [markdown]
# # Problem Statement 17: (Hospitals required to meet the standards)

# %%
govt1['Total_Govt_Hospitals']=govt1['Urban_Government_Hospitals']+govt1['Rural_Government_Hospitals']
govt1['Available_beds']=govt1['Rural_Government_Beds']+govt1['Urban_Government_Beds']
govt1['Bed_gap']=govt1['Expected_beds']-govt1['Available_beds']
govt1['Govt_hospitals_required']=govt1['Bed_gap']/(govt1['Available_beds']/govt1['Total_Govt_Hospitals'])
govt1['Govt_hospitals_required']=govt1['Govt_hospitals_required'].round().astype(float)


#plotting the data
sns.barplot(x='State/UT',y='Govt_hospitals_required',data=govt1.sort_values(by='Govt_hospitals_required',ascending=False))
plt.xticks(rotation=90);
